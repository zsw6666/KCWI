# %%
import numpy as np
import matplotlib.pyplot as plt
import astropy.units as u
import astropy.constants as const
import pandas as pd
from scipy.signal import find_peaks
from lmfit.models import GaussianModel,ConstantModel
from lmfit import Parameters

# %%
from spec_extraction import spec_ly_lib,x_window_ly,y_window_ly,r_ly \
, spec_heii_lib,x_window_heii,y_window_heii,r_heii \
, spec_civ_lib,x_window_civ,y_window_civ,r_civ \
, spec_ly_lib2,x_window_ly2,y_window_ly2,r_ly2 \
, v_ly,v_heii,v_civ,snr_lib,v_lib,ly_noise,heii_noise,civ_noise

# %%
class kinematics:
    def __init__(self,speclib,x):
        self.y=speclib
        self.x=x

    def velocity(self,y_index):

        y=self.y[y_index]/self.y[y_index].max()
        v_aver=(self.x*y).sum()/y.sum()
        return v_aver

    def dispersion(self,y_index):

        v_aver=self.velocity(y_index)
        y=self.y[y_index]/self.y[y_index].max()
        variance=(((self.x-v_aver)**2)*y).sum()/y.sum()
        sigma=np.sqrt(np.abs(variance))

        return sigma
    
    def window(self):
        
        v_lib,sigma_lib=[],[]
        for i in range(self.y.shape[0]):
            v_lib.append(self.velocity(i))
            sigma_lib.append(self.dispersion(i))
        
        return np.array(v_lib),np.array(sigma_lib)
    
class fittor:

    def __init__(self, speclib, lamda):
        self.speclib = speclib
        self.lamda = lamda

    def gaussian_fit(self, x, y, paras=None, method=None):
        g1model = GaussianModel(prefix='g1_')
        g2model = GaussianModel(prefix='g2_')
        g3model = GaussianModel(prefix='g3_')
        cmodel = ConstantModel()
        
        paras = g1model.guess(data=y, x=x)
        paras.update(g2model.make_params())
        paras.update(g3model.make_params())

        paras['g1_amplitude'].set(min=0.)
        paras['g2_amplitude'].set(min=0.)
        paras['g3_amplitude'].set(min=0.)

        paras['g1_center'].set(min=paras['g1_center']-500.,max=paras['g1_center']+500.)
        paras['g2_center'].set(min=paras['g2_center']-500.,max=paras['g2_center']+500.)
        paras['g3_center'].set(min=paras['g3_center']-500.,max=paras['g3_center']+500.)
        
        paras['g1_sigma'].set(min=paras['g1_sigma']-100.,max=paras['g1_sigma']+100.)
        paras['g2_sigma'].set(min=paras['g2_sigma']-100.,max=paras['g2_sigma']+100.)
        paras['g3_sigma'].set(min=paras['g3_sigma']-100.,max=paras['g3_sigma']+100.)

        paras.update(cmodel.make_params())

        model = g1model + g2model + g3model + cmodel

        result = model.fit(y, x=x, params=paras, mothod=method)

        yfit = result.best_fit
        y_para = result.best_values

        residual = y - yfit

        return yfit, y_para, result, residual
    
    def _init_parameter(self,x,y):
        
        peaks, properties = find_peaks(y, prominence=1., width=3,distance=3)
        
        init_para={'g1_center':-200.,'g2_center':200.,'g3_center':0.,
                   'g1_sigma':100.,'g2_sigma':100.,'g3_sigma':100.}
        
    
    def best_fit(self,x,y,paras,criteria,method,inter=200):
        
        sigma_per,k=0.,0
        while sigma_per<0.6:
            yfit,ypara,out,residual=self.gaussian_fit(x,y,paras=paras,method=method)
            sigma_per=residual[(residual>=-criteria)&(residual<=criteria)].size/residual.size
            paras=ypara
            k+=1
            if k>=inter:
                break
                
        return yfit,ypara,out,residual
    
    def lib_fit(self, method,criteria=0.55):
        fitlib = []
        paralib = []
        outlib = []
        residuallib = []
        for i in range(self.speclib.shape[0]):
            
            yfit,para,out,residual=self.best_fit(self.lamda, self.speclib[i, :],init_para,criteria,method)
            fitlib.append(yfit)
            paralib.append(para)
            outlib.append(out)
            residuallib.append(residual)

        return np.array(fitlib), paralib, np.array(residuallib), outlib

# %%
speclib={'ly':spec_ly_lib,'heii':spec_heii_lib,'civ':spec_civ_lib}
kinematicslib={'ly':kinematics(spec_ly_lib,v_ly),
               'heii':kinematics(spec_heii_lib,v_heii),
               'civ':kinematics(spec_civ_lib,v_civ)}

# %%
ly_fittor1=fittor(spec_ly_lib*1e3,v_ly)
fitted_ly,para_ly,residual_ly,out_ly=ly_fittor1.lib_fit(method='shgo')

# %%
properties
# Out:
# {'prominences': array([5.44366863]),
#  'left_bases': array([1]),
#  'right_bases': array([58]),
#  'widths': array([21.97779742]),
#  'width_heights': array([3.11442938]),
#  'left_ips': array([11.23715442]),
#  'right_ips': array([33.21495184])}

# %%
fig,ax=plt.subplots(6,5,sharex=True,sharey='row')
ax=ax.flatten()
for i in range(fitted_ly.shape[0]):
    x=v_ly
    y=spec_ly_lib[i]*1e3
    ax[i].plot(x,y,linewidth=2.,color='black')
    peaks, properties = find_peaks(y, prominence=1., width=3,distance=3)
    ax[i].plot(x[peaks], y[peaks], "x",color='red')
#     ax[i].plot(v_ly,fitted_ly[i],linewidth=2.,color='red')
#     ax[i].step(v_ly,residual_ly[i],linewidth=1.,color='dimgray')
    ax[i].text(600,ax[i].get_ylim()[1].max()*.85,'%.5f'%res)

plt.rcParams['figure.figsize'] = [20,15]
plt.show()
# plt.savefig('fittest.png',dpi=300)

# %%
ss,mm=[],[]
fig,ax=plt.subplots(6,5,sharey='row')
ax=ax.flatten()
for i in range(fitted_ly.shape[0]):
    res=residual_ly[i]*1e3
    ax[i].hist(res,bins=35)
    sigma=0.55#res.std()
    mean=res.mean()
    res_max=res.max()
    sig1_per=res[(res>=-sigma)&(res<=sigma)].size/res.size
    ax[i].text(sigma,8,'%.5f'%mean,fontsize=13.)
    ax[i].text(sigma,4,'%.5f'%sigma,fontsize=13.)
    ax[i].text(sigma,6,'%.5f'%sig1_per,fontsize=13.)
    ax[i].vlines(mean,0,10,color='red',linewidth=3.)
    ax[i].vlines(1*sigma,0,10,color='orange',linewidth=3.)
    ax[i].vlines(-1*sigma,0,10,color='orange',linewidth=3.)
    ax[i].set_ylim(0,10)
    ss.append(sigma)
    mm.append(mean)
    

plt.rcParams['figure.figsize'] = [20,15]
# plt.show()
plt.savefig('fitstatistic.png',dpi=300)
